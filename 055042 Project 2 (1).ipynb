# %% [markdown]
# # Data Visualization (Dashboard) Project 2

# %% [markdown]
# #### IMPORT/EXPORT ANALYSIS OF VARIOUS PRODUCTS

# %% [markdown]
# ##### Submitted to Prof. Amarnath Mitra by Shagun Seth (055042)

# %% [markdown]
# This project aims to establish relevant managerial insights from the given dataset after thorough data visualization using python.

# %% [markdown]
# ##### Data Source

# %% [markdown]
# dataset_source = "https://www.kaggle.com/datasets/chakilamvishwas/imports-exports-15000"

# %% [markdown]
# ## Description of the Data
# This dataset provides detailed information on international trade transactions, capturing both import and export activities. It includes comprehensive data on various aspects of trade, making it a valuable resource for business analysis, economic research, and financial modeling.
#
# Features:
#
# Transaction_ID: Unique identifier for each trade transaction.
# Country: Country of origin or destination for the trade.
# Product: Product being traded.
# Import_Export: Indicates whether the transaction is an import or export.
# Quantity: Amount of the product traded.
# Value: Monetary value of the product in USD.
# Date: Date of the transaction.
# Category: Category of the product (e.g., Electronics, Clothing, Machinery).
# Port: Port of entry or departure.
# Customs_Code: Customs or HS code for product classification.
# Weight: Weight of the product in kilograms.
# Shipping_Method: Method used for shipping (e.g., Air, Sea, Land).
# Supplier: Name of the supplier or manufacturer.
# Customer: Name of the customer or recipient.
# Invoice_Number: Unique invoice number for the transaction.
# Payment_Terms: Terms of payment (e.g., Net 30, Net 60, Cash on Delivery).
# Usage: This dataset can be used for various analyses, including:
#
# Trade Analysis: Understanding trade patterns and trends.
# Economic Research: Studying the impact of trade on different economies.
# Financial Modeling: Evaluating financial performance and risks associated with trade.
# Supply Chain Management: Analyzing logistics and shipping methods.
# Data Format: The dataset is provided in CSV format, making it easy to load into data analysis tools and frameworks.
#
# Additional Notes:
# The dataset consists of 15,000 rows, ensuring a substantial sample size for meaningful analysis.
# Data is generated with realistic variability, simulating actual trade transactions.

# %% [markdown]
# ## Problem Statements:

# %%
#1. What is the total value of transactions by country?
#2. Which product categories contribute the most to transaction value?
#3. How has the transaction value changed over time?
#4. What is the average transaction value by country?
#5. What is average transaction value by category?
#6. How does shipping method affect the transaction value?
#7. Which are the highest number of transactions by payment terms?
#8. Which ports are handling the highest number of transactions?
#9. Who are the top suppliers and customers based on transaction value?
#10. How does weight correlate with transaction value?
#11. What is the transaction frequency by product category?
#12. How is the import/export split by country?
#13. Which country has the highest export value?
#14. How does transaction value vary across months?
#15. What are the most frequently used customs codes?
#16. Does the port of origin/destination affect transaction value?
#17. What is the correlation between the data points?

# %% [markdown]
# ## Project Objectives:

# %% [markdown]
# 1. Total Transaction Value by Country:<br>
# Insight: A visualization and computation of the total transaction value grouped by country.<br>
# Inference: This helps to identify which countries are driving the highest transaction values, potentially revealing important trade partners.<br>
# 2. Product Categories Contribution to Transaction Value:<br>
# Insight: Examines which product categories contribute the most to overall transaction value.<br>
# Inference: Understanding the top-performing product categories enables better supply chain and inventory management by focusing on high-value products.<br>
# 3. Transaction Value Trends Over Time:<br>
# Insight: An analysis of how transaction value changes over different time periods.<br>
# Inference: Recognizing trends over time (e.g., months, years) allows companies to anticipate seasonal demand or market changes.<br>
# 4. Average Transaction Value by Country:<br>
# Insight: Computes the average transaction value for each country.<br>
# Inference: This metric indicates which countries have high-value transactions, which could inform strategic focus or negotiations.<br>
# 5. Transaction Value by Shipping Method:<br>
# Insight: The influence of shipping methods on transaction value is explored.<br>
# Inference: This helps to understand which shipping methods are most cost-effective or value-generating.<br>
# 6. Number of Transactions by Payment Terms:<br>
# Insight: Shows how payment terms affect the number of transactions.<br>
# Inference: Businesses can identify which payment terms are preferred and optimize their offers accordingly.<br>
# 7. Top Ports Handling Transactions:<br>
# Insight: Identifies the ports handling the highest number of transactions.<br>
# Inference: Knowing the busiest ports provides insight into logistics and supply chain efficiency.<br>
# 8. Top Suppliers and Customers by Transaction Value:<br>
# Insight: Highlights the top suppliers and customers based on the transaction value.<br>
# Inference: Enables businesses to focus on maintaining relationships with top partners, while also identifying opportunities for growth.<br>
# 9. Transaction Frequency by Product Category:<br>
# Insight: Explores how frequently different product categories are involved in transactions.<br>
# Inference: High-frequency categories could be prioritized for inventory or sales strategies.<br>
# 10. Import/Export Split by Country:<br>
# Insight: Compares import and export activities across countries.<br>
# Inference: Provides a clear picture of trade balances, helping businesses adjust strategies to align with international demand.<br>
# 11. Correlation Matrix of Features:<br>
# Insight: The correlation matrix identifies relationships between features like quantity, value, weight, and customs code.<br>
# Inference: The matrix shows very weak correlations between the variables, suggesting that no single variable strongly predicts the others. Non-linear models may be more suitable for predictive analysis.<br>
# Collective Insights:<br>
# Country-based Strategy: The analysis reveals the countries contributing the most to total transaction value, indicating where the business should focus its international efforts.<br>
# Product Optimization: Identifying high-value and high-frequency product categories helps in optimizing inventory and supply chain strategies.<br>
# Port and Logistics Insights: The analysis of transaction values by ports provides actionable information on logistics and supply chain efficiency.<br>
# Supplier and Customer Focus: The identification of top suppliers and customers can guide relationship management efforts to focus on the most valuable partnerships.

# %% [markdown]
# # Observations
# Concentration of Value in Few Countries and Categories: A handful of countries and product categories contribute disproportionately to the business value.<br>
# Seasonal Fluctuations: There is clear evidence of seasonal demand, with some months showing much higher transaction values.<br>
# Logistics and Payment Preferences: Shipping methods and payment terms show patterns that indicate customer preferences for certain options based on transaction size or value.<br>
# Concentration in Ports and Partners: A limited number of ports and business partners handle the majority of the transactions, presenting both risks and opportunities for optimization.<br>
# Weak Correlations: Linear relationships between core numerical variables are weak, meaning that other factors (perhaps non-linear or qualitative) might be influencing the business outcomes.

# %% [markdown]
# # Strategic Recommendations

# %% [markdown]
# 1. Prioritize High-Value Countries<br>
# Recommendation: Focus resources on countries that contribute the most to transaction value. This could involve increasing marketing efforts, expanding the product range, and fostering deeper relationships with key customers in these regions.<br>
# Action: Allocate more sales and logistics resources to top-performing countries and tailor marketing campaigns to their specific needs and preferences. Investigate why low-performing countries aren't delivering results—consider modifying product offerings, pricing, or distribution strategies.<br>
# 2. Maximize Opportunities in High-Value Product Categories<br>
# Recommendation: Focus on maintaining strong inventory levels for high-value product categories and consider expanding related product lines. These categories are essential to the business's core revenue, so they must be prioritized in supply chain management and marketing.<br>
# Action: Negotiate better supplier deals for these products, increase promotion, and ensure they remain top-of-mind for customers through strategic pricing and exclusive offers.<br>
# 3. Develop Seasonality Strategies<br>
# Recommendation: Since transaction values fluctuate significantly across different months, capitalize on peak periods by ensuring sufficient inventory and targeted marketing during those times. During slower months, consider introducing promotions to maintain cash flow.<br>
# Action: Create a promotional calendar aligned with the months of high transaction value and plan for stock replenishment in advance. For slower months, offer discounts or bundle deals to stimulate demand.<br>
# 4. Optimize Shipping Costs and Efficiency<br>
# Recommendation: Align shipping methods with the value of transactions. For high-value items, invest in premium, reliable shipping. For lower-value products, focus on cost-efficient shipping methods.<br>
# Action: Develop tiered shipping strategies that match the value and urgency of the products. Negotiate better rates with shipping companies for the high-volume routes and ports identified.<br>
# 5. Leverage Customer Payment Preferences<br>
# Recommendation: Standardize and promote the most popular payment terms used by customers. Offering preferred payment terms can increase customer satisfaction, resulting in higher transaction volumes.<br>
# Action: If customers prefer longer credit terms or cash payments, implement and advertise those options more broadly. For markets or regions with less popular payment terms, consider offering more flexible or tailored payment solutions.<br>
# 6. Strengthen Key Supplier and Customer Relationships<br>
# Recommendation: Focus on developing stronger partnerships with the few suppliers and customers that contribute the most to your transaction value. Offer loyalty programs or exclusive deals to retain and grow these relationships.<br>
# Action: Create tailored offers for key partners, including volume discounts or preferred terms. Consider joint ventures or strategic partnerships to secure long-term supply or demand stability.<br>
# 7. Diversify Risk in Ports and Logistics<br>
# Recommendation: Since a small number of ports handle the majority of transactions, there is a risk of over-dependence. Explore alternative routes or ports to reduce risks associated with disruptions (e.g., strikes, congestion).<br>
# Action: Conduct a risk assessment of current port operations and consider diversifying to additional ports that may offer more cost-effective or reliable alternatives, even if they currently handle fewer transactions.<br>
# 8. Enhance Supply Chain for High-Volume Customs Codes<br>
# Recommendation: Streamline processes related to frequently used customs codes by automating documentation and ensuring compliance. This will reduce delays and potential errors in processing.<br>
# Action: Invest in digital solutions or software that can automatically handle frequently used customs codes, making customs clearance faster and more reliable.<br>
# 9. Implement Advanced Analytics for Non-Linear Relationships<br>
# Recommendation: Since the correlation matrix suggests weak linear relationships between key numeric variables, consider using advanced analytics (e.g., machine learning) to uncover hidden patterns or relationships that traditional linear models may miss.<br>
# Action: Invest in predictive analytics tools and techniques, such as decision trees, clustering, or regression analysis, to better understand the drivers of transaction value and improve decision-making.<br>
# 10. Focus on Customer Segmentation and Personalization<br>
# Recommendation: The dataset shows varying transaction values by country and product categories. Segmenting customers based on purchasing behavior and customizing the approach (e.g., product offerings, payment terms, promotions) will help maximize engagement.<br>
# Action: Conduct customer segmentation analysis to tailor product offerings, shipping methods, and promotions based on customer behavior. This can enhance customer satisfaction and retention in high-value segments.<br>
# 11. Boost Performance in Low-Value Countries and Categories<br>
# Recommendation: For countries or product categories with low transaction values, reassess the market strategy. There might be opportunities to boost performance through targeted promotions, new product introductions, or more efficient distribution methods.<br>
# Action: Run market analysis or surveys in low-performing regions to understand consumer preferences and needs. Explore whether adjustments to pricing, product selection, or localized marketing efforts can drive improvement.<br>

# %% [markdown]
# ##### Importing Relevant Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import streamlit as st

# %% [markdown]
# ##### Loading the Project's Data

# %%
file_path = r'/Users/shagunseth/Desktop/ImportsExportsDataset.csv' #Load the Test Data.
project=pd.read_csv(file_path)
my_project= pd.DataFrame(project);
my_project
# Out:
#                              Transaction_ID           Country    Product  \
# 0      e3e70682-c209-4cac-a29f-6fbed82c07cd          Colombia   describe
# 1      f728b4fa-4248-4e3a-8a5d-2f346baa9455             Chile  president
# 2      eb1167b3-67a9-4378-bc65-c1e582e2e662            Turkey        far
# 3      f7c1bd87-4da5-4709-9471-3d60c8a70639  Christmas Island     agency
# 4      e443df78-9558-467f-9ba9-1faf7a024204           Finland     policy
# ...                                     ...               ...        ...
# 14995  48df15a8-0823-4964-8c16-eddf2756f382  Marshall Islands        not
# 14996  31106617-94a6-4646-a001-5e7bd45abc26           Bermuda        air
# 14997  ee485839-fbde-4ced-af18-d98f5e863081          Tanzania       show
# 14998  5acd54aa-ec8c-4055-be8b-a447861a471c            Tuvalu         TV
# 14999  5cc039d0-a052-41fd-bfbb-c9f60c4565ac   North Macedonia       year
#
#       Import_Export  Quantity    Value        Date     Category  \
# ...

# %%
my_project.shape
# Out:
# (15000, 16)

# %% [markdown]
# ##### Creating a Unique Sample of 3001 Records using Student Roll Number as Random State.

# %%
my_sample=my_project.sample(n=3001, random_state=55042) 
rows, columns = my_sample.shape
print(f"Number of rows: {rows}, Number of columns: {columns}")
# Out:
# Number of rows: 3001, Number of columns: 16

# %% [markdown]
# ##### Data Type:

# %%
my_sample.dtypes
# Out:
# Transaction_ID      object
# Country             object
# Product             object
# Import_Export       object
# Quantity             int64
# Value              float64
# Date                object
# Category            object
# Port                object
# Customs_Code         int64
# Weight             float64
# Shipping_Method     object
# Supplier            object
# Customer            object
# Invoice_Number       int64
# Payment_Terms       object
# dtype: object

# %% [markdown]
# ##### Data Dimension:

# %%
my_sample.shape
# Out:
# (3001, 16)

# %% [markdown]
# ##### Data Variable Type:

# %%
my_sample.info
# Out:
# <bound method DataFrame.info of                             Transaction_ID                     Country  \
# 5681  5a2d5998-fd1a-41e2-b289-6e548c8268ff                     Finland
# 5289  9344741b-6fdf-46e8-b9c4-22581e44da98                    Malaysia
# 7460  91e6f15e-b170-4040-bbc4-b4b2a018ef61                   Nicaragua
# 5442  0e19967b-8102-4e40-9b93-5e6128d1af89                Sierra Leone
# 6387  cfccc992-429c-4571-bb37-9aa7d7b63517                 Switzerland
# ...                                    ...                         ...
# 4668  3b9a6173-95fc-4b15-a4d6-f5c8ea3e943a    Northern Mariana Islands
# 993   f65a1a2a-4f76-4aac-9ec2-2e0cd4cd82fa                     Algeria
# 2022  2eccb98e-b157-4ce1-b3b9-426df25dcd20  Slovakia (Slovak Republic)
# 7941  9c2b4d4c-ca7f-40cf-b485-16db0376fedf                  San Marino
# 6824  e7d7391d-7f0e-4945-b83c-33b54ecfb573                      Panama
#
#         Product Import_Export  Quantity    Value        Date     Category  \
# ...

# %% [markdown]
# ##### Sample Information:

# %%
#Display the First 03 Records of the Sample Data.
my_sample.head(3)
# Out:
#                             Transaction_ID    Country   Product Import_Export  \
# 5681  5a2d5998-fd1a-41e2-b289-6e548c8268ff    Finland  daughter        Import
# 5289  9344741b-6fdf-46e8-b9c4-22581e44da98   Malaysia    relate        Export
# 7460  91e6f15e-b170-4040-bbc4-b4b2a018ef61  Nicaragua   between        Import
#
#       Quantity    Value        Date   Category            Port  Customs_Code  \
# 5681      3049  4898.26  19-09-2020  Furniture  Christinehaven        484720
# 5289      8723  1558.82  14-12-2023  Machinery     Jessicaland        239252
# 7460      8875  5350.18  14-07-2020  Machinery       Ryanmouth        442561
#
#        Weight Shipping_Method                   Supplier         Customer  \
# 5681  3182.44             Sea    Owens, Moore and Abbott    Rhonda Newman
# 5289   692.66            Land  Johnson, Weber and Flores  Jonathan Hanson
# 7460   388.85             Air                 Wilson PLC     Philip Smith
#
#       Invoice_Number     Payment_Terms
# ...

# %%
#Obtain the column names of the pandas DataFrame
my_sample.columns.tolist()
# Out:
# ['Transaction_ID',
#  'Country',
#  'Product',
#  'Import_Export',
#  'Quantity',
#  'Value',
#  'Date',
#  'Category',
#  'Port',
#  'Customs_Code',
#  'Weight',
#  'Shipping_Method',
#  'Supplier',
#  'Customer',
#  'Invoice_Number',
#  'Payment_Terms']

# %% [markdown]
# ##### Data Variable Category:

# %%
#Identify & Display the List of the following Variables:
# 1. Index Variables[Transaction_ID]
# 2. Categorical Variables - Nominal Type [Country, Product, Import_Export, Category, Port, Customs_Code, Shipping_Method, Supplier, Customer, Invoice_Number]
# 3. Categorical Variables - Ordinal Type. [Payment_Terms]
# 4. Non-Categorical Variables [Quantity, Value, Date, Weight]

# %% [markdown]
# #### Subseting Categorical & Non Categorical Variables and Finding Descriptive Statistics of both

# %%
#Subset and Display the Non-Categorical Variables.
non_categorical = my_sample[['Quantity', 'Value', 'Date', 'Weight']]
non_categorical
# Out:
#       Quantity    Value        Date   Weight
# 5681      3049  4898.26  19-09-2020  3182.44
# 5289      8723  1558.82  14-12-2023   692.66
# 7460      8875  5350.18  14-07-2020   388.85
# 5442      5407  4412.36  15-07-2023  3210.66
# 6387      5009  9101.21  17-12-2020   351.86
# ...        ...      ...         ...      ...
# 4668      7995  8901.81  25-10-2023   831.89
# 993       6012  3078.85  08-10-2021  3212.64
# 2022       981  3539.58  30-05-2024  4376.61
# 7941       364  2220.21  30-03-2024  2036.32
# 6824      1051  3726.82  27-06-2021  3792.68
#
# [3001 rows x 4 columns]

# %%
#Display the Descriptive Statistics of the Non-Categorical Subset.
non_categorical.describe()
# Out:
#           Quantity        Value       Weight
# count  3001.000000  3001.000000  3001.000000
# mean   4953.753082  5045.758281  2494.373342
# std    2867.051857  2857.580004  1445.773041
# min       8.000000   102.870000     3.690000
# 25%    2455.000000  2567.260000  1258.080000
# 50%    4913.000000  5084.150000  2462.940000
# 75%    7420.000000  7522.090000  3749.610000
# max    9995.000000  9999.130000  4997.130000

# %%
#Subset and Display the Categorical Variables.
my_categorical = my_sample[['Country', 'Product', 'Import_Export', 'Category', 'Port', 'Customs_Code', 'Shipping_Method', 'Supplier', 'Customer', 'Invoice_Number']]
my_categorical
# Out:
#                          Country    Product Import_Export     Category  \
# 5681                     Finland   daughter        Import    Furniture
# 5289                    Malaysia     relate        Export    Machinery
# 7460                   Nicaragua    between        Import    Machinery
# 5442                Sierra Leone  direction        Export     Clothing
# 6387                 Switzerland    present        Import    Furniture
# ...                          ...        ...           ...          ...
# 4668    Northern Mariana Islands   strategy        Import     Clothing
# 993                      Algeria       base        Export    Machinery
# 2022  Slovakia (Slovak Republic)      write        Import  Electronics
# 7941                  San Marino        buy        Import    Machinery
# 6824                      Panama       news        Export     Clothing
#
#                     Port  Customs_Code Shipping_Method  \
# 5681      Christinehaven        484720             Sea
# ...

# %%
#Display the Descriptive Statistics of any 02 Categorical Variables.
my_categorical02 = my_sample[['Country','Product']]
my_categorical02.value_counts()
# Out:
# Country              Product
# Croatia              material     2
# French Guiana        movie        2
# American Samoa       happy        2
# Trinidad and Tobago  wrong        2
# American Samoa       maybe        2
#                                  ..
# Gibraltar            suddenly     1
#                      then         1
#                      year         1
# Greece               available    1
# Zimbabwe             style        1
# Name: count, Length: 2981, dtype: int64

# %% [markdown]
# ## Data Visualisation With Insights:

# %% [markdown]
# #1. What is the total value of transactions by country?

# %%
# Grouping by 'Country' and calculating the total value of transactions for each country
country_value = my_sample.groupby('Country')['Value'].sum()

# Sorting the values in descending order
country_value_sorted = country_value.sort_values(ascending=False)

# Visualization
plt.figure(figsize=(12, 6))
country_value_sorted.plot(kind='bar', color='skyblue')

# Title and labels
plt.title('Total Transaction Value by Country')
plt.xlabel('Country')
plt.ylabel('Total Value')

# Set xticks, showing every 10th label to avoid overcrowding
plt.xticks(ticks=range(0, len(country_value_sorted), 10), labels=country_value_sorted.index[::10], rotation=45)  

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %% [markdown]
# Key Insights:
# Top Markets: Egypt, Malaysia, and Azerbaijan contribute the most to transaction value, indicating key markets.
# Market Concentration: A significant portion of value comes from a few countries, with a sharp decline after the top contributors.
# Smaller Markets: There’s a long tail of smaller markets, offering growth potential if further developed.
# Suggestions:
# Strengthen Key Markets: Focus on maintaining and enhancing relationships with top-performing countries.
# Diversify Risk: Expand efforts in mid-tier markets like Switzerland and Oman to reduce over-reliance on a few countries.
# Explore Growth in Smaller Markets: Tailor marketing efforts to smaller countries for potential long-term growth.

# %% [markdown]
# #2. Which product categories contribute the most to transaction value?

# %%
# Sum of transaction value by product category
category_value = my_sample.groupby('Category')['Value'].sum()

# Visualization
plt.figure(figsize=(8, 8))
category_value.plot(kind='pie', autopct='%1.1f%%', startangle=140, cmap='viridis')
plt.title('Contribution of Product Categories to Transaction Value')
plt.ylabel('')
plt.tight_layout()
plt.show()

# %% [markdown]
# Key Insights:
# Even Category Distribution: The pie chart shows a fairly even split among product categories, with no single category drastically outweighing the others.
# Top Categories: Clothing (20.7%), Machinery (20.4%), and Furniture (19.9%) make up the largest contributions, indicating these are key revenue drivers.
# Suggestions:
# Leverage Leading Categories: Since Clothing, Machinery, and Furniture lead the contributions, you should focus on optimizing these categories with targeted promotions or expanding product lines to further drive sales.
# Monitor Lesser Categories: Electronics and Toys have slightly lower contributions. Assess if there’s potential to grow these segments through innovative offerings or improved marketing efforts, or consider reallocating resources to more profitable categories if needed.

# %% [markdown]
# #3. How has the transaction value changed over time?

# %%
# Convert 'Date' to datetime with correct format and parameters
my_sample['Date'] = pd.to_datetime(my_sample['Date'], dayfirst=True, format='%d-%m-%Y')

# Monthly trend in transaction values using the correct resample parameter
monthly_trend = my_sample.resample('ME', on='Date')['Value'].sum()

# Visualization
plt.figure(figsize=(12, 6))
plt.plot(monthly_trend.index, monthly_trend.values, marker='o', color='green')
plt.title('Monthly Trend in Total Transaction Values')
plt.xlabel('Month')
plt.ylabel('Total Value')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Key Insights:
# Fluctuating Trend: The chart shows a highly fluctuating monthly trend in total transaction values, with notable spikes and drops, indicating potential seasonality or inconsistent demand.
# Recent Decline: The steep drop at the end of the timeline (2024) suggests a significant recent decline in transaction value, which could be concerning and warrants investigation.
# Suggestions:
# Investigate Recent Drop: The sharp decline in 2024 should be analyzed to identify possible causes (e.g., market shifts, external factors, internal issues). Immediate action may be needed to mitigate further losses.
# Stabilize Transaction Volumes: Implement strategies to smooth out fluctuations, such as demand forecasting or promotional campaigns during lower months to maintain steadier transaction values.

# %% [markdown]
# #4. What is the average transaction value by country?

# %%
# Average transaction value by country (top 15 countries)
top_avg_value = average_value.sort_values(ascending=False).head(15)

# Visualization
plt.figure(figsize=(10, 6))
top_avg_value.plot(kind='bar', color='orange')
plt.title('Average Transaction Value by Top 15 Countries')
plt.xlabel('Country')
plt.ylabel('Average Value')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 # Average transaction value by country (top 15 countries)
# ----> 2 top_avg_value = average_value.sort_values(ascending=False).head(15)
#       4 # Visualization
#       5 plt.figure(figsize=(10, 6))
#
# NameError: name 'average_value' is not defined

# %% [markdown]
# The chart shows that countries like the United States Minor Outlying Islands, Hong Kong SAR, and Moldova have the highest average transaction values, indicating lucrative markets. Smaller regions like Wallis and Futuna and Sao Tome and Principe also show high-value transactions, suggesting niche or premium markets.
#
# Suggestion:
# Focus on these high-value regions for premium or specialized products and services to maximize profits and capture high-spending customer segments.

# %% [markdown]
# #5. What is average transaction value by category?

# %%
# Calculate average transaction value by category
average_value_by_category = my_sample.groupby('Category')['Value'].mean().sort_values(ascending=False)

# Visualization
plt.figure(figsize=(12, 6))
average_value_by_category.plot(kind='bar', color='purple')
plt.title('Average Transaction Value by Category')
plt.xlabel('Category')
plt.ylabel('Average Value')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# #6. How does shipping method affect the transaction value?

# %%
#Box plot of transaction value by shipping method 
plt.figure(figsize=(10, 6))
my_sample.boxplot(column='Value', by='Shipping_Method', grid=False)
plt.title('Shipping Method vs. Transaction Value')
plt.suptitle('')
plt.xlabel('Shipping Method')
plt.ylabel('Transaction Value')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Business Insight:
# The similar transaction values across categories suggest that these product categories are equally valued by customers. There's no clear dominance of one category over the others, indicating balanced consumer spending across these sectors.<BR>
# Suggestion:
# Since no single category stands out significantly, businesses can diversify their offerings across these categories to maintain a balanced revenue stream. Exploring cross-selling opportunities between these categories can also drive higher transaction values.

# %% [markdown]
# #7. Which are the highest number of transactions by payment terms?

# %%
# Number of transactions by payment terms
payment_terms_counts = my_sample['Payment_Terms'].value_counts()

# Visualization
plt.figure(figsize=(10, 6))
payment_terms_counts.plot(kind='bar', color='purple')
plt.title('Frequency of Payment Terms Used')
plt.xlabel('Payment Terms')
plt.ylabel('Number of Transactions')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Business Insight:
# Customers appear to prefer flexible payment terms, with a balanced distribution across all options. Cash on Delivery is the most common, suggesting that consumers value the security of paying upon receipt.<BR>
# Suggestion:
# To increase transaction volume, consider promoting Cash on Delivery in markets where trust is a barrier. Additionally, offering incentives for Prepaid options (e.g., discounts or faster shipping) may encourage customers to choose this method, improving cash flow for the business.

# %% [markdown]
# #8. Which ports are handling the highest number of transactions?

# %%
# Number of transactions by port
port_counts = my_sample['Port'].value_counts()

# Visualization
plt.figure(figsize=(10, 6))
port_counts.sort_values(ascending=False).head(10).plot(kind='bar', color='teal')
plt.title('Top 10 Ports by Number of Transactions')
plt.xlabel('Port')
plt.ylabel('Number of Transactions')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# The bar chart shows the top 10 ports by the number of transactions, with Lake Michael and New Joseph leading the count at 6 transactions each. This suggests that these two ports are critical hubs for business activity. The other ports, such as Port David, West Michael, and East Lisa, have slightly fewer transactions, but they still contribute significantly to the overall volume.
#
# Business Insight:
# Concentration of Activity: The top two ports account for more transactions than the rest, indicating potential key distribution or transaction centers. Optimizing resources around these top-performing ports could lead to efficiency gains.
#
# Transaction Distribution: While a few ports dominate, there is a steady flow across all listed ports, implying a balanced network. Smaller ports, like Jonestown and Lake Daniel, still contribute and shouldn't be overlooked.
#
# Suggestion:
# Expand Capacity and Optimize Operations at High-Volume Ports: Given the higher transaction volume at Lake Michael and New Joseph, consider enhancing infrastructure, logistics, and personnel resources at these ports to improve efficiency and handle future growth. Also, monitor and promote underperforming ports to balance load distribution.

# %% [markdown]
# #9. Who are the top suppliers and customers based on transaction value?

# %%
# Sum of transaction value by supplier
supplier_value = my_sample.groupby('Supplier')['Value'].sum().sort_values(ascending=False).head(10)

# Visualization
plt.figure(figsize=(10, 6))
supplier_value.plot(kind='bar', color='red')
plt.title('Top 10 Suppliers by Transaction Value')
plt.xlabel('Supplier')
plt.ylabel('Total Value')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# The bar chart highlights the top 10 suppliers by transaction value, with Johnson PLC and Johnson Group leading the list at transaction values over 30,000. This suggests a concentration of high-value transactions among these suppliers, indicating their importance in the supply chain. Other significant suppliers, such as Vargas LLC and Smith PLC, also contribute notable values, though slightly lower.
#
# Business Insight:
# Supplier Dominance: Johnson PLC and Johnson Group are key players, likely controlling a large portion of business transactions. This reliance could pose a risk if these suppliers face disruptions or negotiate for more favorable terms due to their significance.
#
# Diverse Supplier Base: While a few suppliers dominate, there is still a healthy mix, with Smith PLC, Walker Inc, and others contributing substantial value. This suggests the business maintains some diversity in its supplier base.
#
# Suggestion:
# Diversify Supplier Relationships: Since Johnson PLC and Johnson Group represent significant portions of transaction value, consider diversifying procurement sources to reduce risk and dependency. Strengthening relationships with smaller suppliers like Jones Inc and White and Sons could lead to better negotiation leverage and more flexible supply chain options in the long run.

# %% [markdown]
# #10. How does weight correlate with transaction value?

# %%
import seaborn as sns
import numpy as np
my_sample['Weight'] = my_sample['Weight'].astype(float)  
my_sample['Value'] = my_sample['Value'].astype(float)    

# Creating a scatter plot with regression line
plt.figure(figsize=(12, 8))
sns.scatterplot(data=my_sample, x='Weight', y='Value', hue='Shipping_Method', size='Quantity', sizes=(20, 200), alpha=0.6, palette='viridis')

# Adding a regression line
sns.regplot(data=my_sample, x='Weight', y='Value', scatter=False, color='black', ci=None)

plt.title('Weight vs. Transaction Value with Shipping Method and Quantity')
plt.xlabel('Weight')
plt.ylabel('Transaction Value')
plt.grid(True)
plt.tight_layout()
plt.legend(title='Shipping Method', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# The scatter plot illustrates the relationship between weight and transaction value, with the color representing the shipping method (Sea, Land, Air) and the size of each point representing the quantity of items. Additionally, a regression line is included to highlight the trend between weight and transaction value.
#
# Business Insight:
# No Clear Correlation: The data points are widely dispersed, and the regression line is nearly flat, indicating no strong linear relationship between weight and transaction value. This suggests that higher-weight shipments don't necessarily correspond to higher transaction values.
#
# Shipping Method and Quantity: There appears to be no clear dominance of a specific shipping method in relation to transaction value. Sea shipping seems to handle both high and low transaction values across various weights, while Air shipping may lean towards higher-value, lighter-weight items.
#
# Quantity and Value Variations: Larger quantities do not necessarily drive up transaction values, as indicated by the varying point sizes.
#
# Suggestion:
# Optimize Shipping Method Based on Transaction Value: Since there's no clear link between weight and value, it may be worthwhile to analyze shipping efficiency and cost-effectiveness based on value. For high-value but low-weight items, Air shipping could be optimized for faster delivery. For larger shipments with lower values, Sea or Land methods may offer better cost efficiency. Implementing shipping cost analysis based on value and weight could reveal opportunities for savings.

# %% [markdown]
# #11. What is the transaction frequency by product category?

# %%
# Transaction frequency by product category
category_freq = my_sample['Category'].value_counts()

# Visualization
plt.figure(figsize=(10, 6))
category_freq.plot(kind='bar', color='grey')
plt.title('Transaction Frequency by Product Category')
plt.xlabel('Product Category')
plt.ylabel('Number of Transactions')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Business Insight:
# Clothing leads in terms of transaction frequency, suggesting that it is the most popular or demanded product category among customers.
# Machinery, Furniture, Toys, and Electronics all have similar transaction counts, though slightly behind Clothing. This indicates these categories are also performing well, but none is dominating the sales in the same way as Clothing.<BR>
# Suggestion:
# Focus on Clothing: Since Clothing is the top-selling category, it would be beneficial to further invest in this area by increasing inventory, promoting sales, or introducing new styles to capitalize on its popularity.
# Diversify Marketing Efforts: To reduce over-reliance on one category, consider targeted promotions or discounts on other categories like Electronics or Furniture to boost their sales.
# Customer Feedback: Conduct a survey to understand why customers prefer Clothing more and apply those insights to enhance other product categories.

# %% [markdown]
# #12. How is the import/export split by country?

# %%
# Calculate total import/export value by country
import_export_split = my_sample.groupby(['Country', 'Import_Export'])['Value'].sum().unstack().fillna(0)

# Sum across all countries to determine top N countries
top_n = 10  # Change this number to display more or fewer countries
top_countries = import_export_split.sum(axis=1).nlargest(top_n).index
import_export_split = import_export_split.loc[top_countries]

# Visualization
plt.figure(figsize=(12, 8))
ax = import_export_split.plot(kind='barh', stacked=True, color=['orange', 'green'], edgecolor='black')

# Adding data labels
for container in ax.containers:
    ax.bar_label(container, fmt='%.0f', label_type='center', color='white', fontsize=10)

# Titles and labels
plt.title('Top Import vs. Export Value per Country')
plt.xlabel('Total Value')
plt.ylabel('Country')
plt.tight_layout()
plt.legend(title='Import/Export', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# Business Insight:
# Sierra Leone has a significantly higher export value compared to import, indicating a strong export economy relative to its import needs.<BR>
# Congo and Montserrat also show higher import values than export, which could point to reliance on foreign goods or materials.<BR>
# Countries like Suriname, Panama, and Korea have a more balanced import-export value, which suggests a well-maintained trade equilibrium.<BR>
# Egypt has a strong import value, which might indicate an increased dependency on imports or a large demand for foreign goods compared to domestic production.<BR>
# Suggestion:<BR>
# Focus on Trade Balancing Opportunities: For countries with a significant imbalance (e.g., Sierra Leone for exports and Congo for imports), explore opportunities for boosting the weaker side. Sierra Leone could diversify its import channels, while Congo could work on strengthening domestic industries to reduce import dependency.<BR>
# Leverage Balanced Trade: For countries with a more balanced trade like Suriname and Korea, build on this stability to create long-term trade partnerships, focusing on optimizing cost and efficiency in both import and export logistics.<BR>
# Market-Specific Strategy: Tailor marketing and investment strategies based on a country’s trade strengths. For example, in export-heavy countries like Sierra Leone, companies might prioritize international market expansion, whereas in import-reliant regions like Congo, import-focused businesses might find better growth opportunities.

# %% [markdown]
# #13. Which country has the highest export value?

# %%
# Filter data for exports only
export_data = my_sample[my_sample['Import_Export'] == 'Export']
country_export_value = export_data.groupby('Country')['Value'].sum()

# Sort values and select top N countries
top_n = 10  # Change this number to display more or fewer countries
top_export_countries = country_export_value.nlargest(top_n)

# Calculate the percentage contribution of each country
total_export_value = top_export_countries.sum()
percentage_contribution = (top_export_countries / total_export_value) * 100

# Visualization
plt.figure(figsize=(12, 8))
ax = top_export_countries.sort_values(ascending=True).plot(kind='barh', color='lime', edgecolor='black')

# Adding annotations for values and percentages using iloc
for i, (country, value) in enumerate(top_export_countries.sort_values(ascending=True).items()):
    ax.text(value + 0.02 * total_export_value, i, f'{value:,.0f} ({percentage_contribution.iloc[i]:.1f}%)', color='black', va='center')

# Titles and labels
plt.title('Top Export Value by Country')
plt.xlabel('Total Export Value')
plt.ylabel('Country')
plt.axvline(x=total_export_value, color='red', linestyle='--', label='Total Export Value')  # Optional line
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Business Insight:<BR>
# Indonesia contributes the highest percentage to total export value at 12.2%, followed by Tanzania and Mauritius. These countries have a significant share in the overall export market.<BR>
# Sierra Leone, Northern Mariana Islands, and Azerbaijan also contribute notable amounts, although slightly lower, indicating their substantial involvement in exports.<BR>
# The distribution shows that even though several countries are close in their export values, the top contributor (Indonesia) is still a clear leader compared to others.<BR>
# Suggestion:<BR>
# Invest in High-Exporting Countries: Countries like Indonesia, Tanzania, and Mauritius are already strong exporters. Strengthening relationships, optimizing supply chains, or exploring new trade agreements in these regions could yield significant growth opportunities.<BR>
# Diversify Export Markets: While the top contributors dominate, exploring ways to boost exports from countries lower on the list (like Korea and Gibraltar) could help diversify revenue streams and reduce dependency on a few regions.<BR>
# Leverage Dominance in Leading Markets: For countries like Indonesia, which already holds a strong position, focus on enhancing productivity or expanding the variety of export products to maintain and increase market share globally.

# %% [markdown]
# #14. How does transaction value vary across months?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Convert 'Date' column to datetime format
my_sample['Date'] = pd.to_datetime(my_sample['Date'], dayfirst=True)

# Resample to calculate total transaction value by month
monthly_value = my_sample.resample('ME', on='Date')['Value'].sum()  # Use 'ME' for month-end

# Visualization
plt.figure(figsize=(12, 6))
plt.plot(monthly_value.index, monthly_value.values, marker='o', linestyle='-', color='blue')
plt.title('Total Monthly Transaction Value')
plt.xlabel('Month')
plt.ylabel('Total Value')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Business Insight:
#
# Volatility: There is notable fluctuation in monthly transaction values, with several sharp peaks and troughs. This indicates potential variability in demand, seasonality, or other external factors affecting transactions.<BR>
# Decline: While the transaction value is mostly stable around 250,000–300,000 for a significant period, a sharp decline is observed towards the end of the period (2024), potentially signaling recent operational or market issues.<BR>
# Recovery Cycles: Over the years, dips are consistently followed by recoveries, which may suggest resilience or cyclical market behavior.<BR>
#
# Suggestion:<BR>
# To address the recent sharp decline, it would be valuable to investigate the cause behind this downturn. Whether it stems from market shifts, operational inefficiencies, or customer behavior changes, swift action is needed. Diversifying product/service offerings or adjusting marketing strategies to stabilize revenues during slower periods could help mitigate these risks and smooth out the volatility in transaction values.

# %% [markdown]
# #15. What are the most frequently used customs codes?

# %%
# Frequency of customs codes
customs_code_counts = my_sample['Customs_Code'].value_counts().head(10)

# Visualization
plt.figure(figsize=(10, 6))
customs_code_counts.plot(kind='bar', color='darkblue')
plt.title('Top 10 Customs Codes by Frequency')
plt.xlabel('Customs Code')
plt.ylabel('Number of Transactions')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# The graph highlights the top 10 customs codes by the number of transactions, with a few codes (e.g., 453072, 969808, 349924, 758816) being more frequently used, all having a transaction count close to two.<BR>
# Business Insight:<BR>
# Concentration: A few customs codes dominate the transaction landscape, which indicates that specific products or categories are more commonly involved in trade. This suggests that the business may be reliant on a limited range of goods or services.
# Diversity in Transaction Volume: Some customs codes appear less frequently, indicating potential underutilization or less demand for certain categories.<BR>
# Suggestion:<BR>
# The company should consider analyzing the high-frequency codes in greater detail, understanding what makes these categories more successful. Simultaneously, focus on exploring opportunities for the lesser-used codes, perhaps through targeted marketing, better pricing strategies, or addressing logistical barriers. Expanding the diversity of products handled can help reduce risk from over-reliance on a few key categories.<BR>

# %% [markdown]
# #16. Does the port of origin/destination affect transaction value?

# %%
import seaborn as sns

# Calculate the top N ports based on total transaction value
top_n = 10  # Change this number as needed
top_ports = my_sample.groupby('Port')['Value'].sum().nlargest(top_n).index

# Filter the dataset for top ports
filtered_data = my_sample[my_sample['Port'].isin(top_ports)]

# Create a combined box plot and violin plot
plt.figure(figsize=(12, 8))
# Update the scale parameter to density_norm
sns.violinplot(x='Port', y='Value', data=filtered_data, inner=None, color='lightgray', density_norm='count')
sns.boxplot(x='Port', y='Value', data=filtered_data, color='lightblue', width=0.4)

# Add title and labels
plt.title('Transaction Value by Port of Origin/Destination (Top Ports)')
plt.xlabel('Port')
plt.ylabel('Transaction Value')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()

# Adding statistical annotations
for port in top_ports:
    data_port = filtered_data[filtered_data['Port'] == port]
    median_val = data_port['Value'].median()
    plt.annotate(f'Median: {median_val:,.0f}', 
                 xy=(port, median_val), 
                 xytext=(port, median_val + 5000),  # Adjust vertical position as needed
                 arrowprops=dict(facecolor='black', arrowstyle='->'),
                 ha='center')

plt.show()

# %% [markdown]
# The violin plot and box plot visualize the distribution of transaction values for the top 10 ports. Here’s a breakdown:<BR>
#
# Business Insight:<BR>
# Highest Median Transaction Values: Ports like Lake Jason (median 9,301) and Lake Michael (median 8,824) demonstrate higher transaction values, indicating they are key revenue-generating hubs.<BR>
# Lower Transaction Values: Ports such as Smithchester and Port David have lower median transaction values (3,520 and 3,390, respectively). These ports show a wider variance in transaction amounts, with transactions potentially involving both small and large values.<BR>
# Port Performance Consistency: Some ports (e.g., Lake Jason and West Michael) show tighter distributions around the median, suggesting consistent transaction volumes. Others, like Smithchester and Port David, display broader ranges and more variability.<BR>
# Suggestion:<BR>
# Focus on increasing business at high-performing ports (Lake Jason and Lake Michael), while analyzing why Smithchester and Port David show such variability. There could be logistical or pricing issues affecting performance at these ports. Consider streamlining operations or improving customer experience at the underperforming ports to bring them in line with higher-performing locations.

# %% [markdown]
# #17. What is the correlation between the data points?

# %%
#correlation of data
my_sample.corr( numeric_only = True)

# Compute the correlation matrix
corr_matrix = my_sample.corr(numeric_only=True)

# Set up the matplotlib figure
plt.figure(figsize=(10, 8))

# Create a heatmap
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5, fmt='.2f')

# Add labels and title
plt.title('Correlation Matrix of Numeric Features')
plt.show()

# %% [markdown]
# Business Insight:<br>
# Weak or No Correlation:<br>
# The matrix shows weak or negligible correlations between the features, with most values close to 0. For instance, the correlation between Quantity and Value is only 0.04, indicating almost no linear relationship.<br>
# Weight and Value are also weakly correlated (0.00), suggesting that weight does not influence the value significantly in this data.
# Customs Code Independence:<br>
# The Customs Code shows no significant correlation with other numeric features, which makes sense since it represents categorical or classification-type data rather than a continuous variable.<br>
# Invoice Number:<br>
# The Invoice Number has very weak correlations with other features like Quantity (-0.01) and Weight (0.02). This implies that invoice identification is independent of these attributes.<br>
# Suggestion:<br>
# Feature Engineering: The absence of strong correlations suggests that these features might not be the most predictive or useful for building analytical models such as regression. It may be worthwhile to explore additional features or transform the existing features. Consider creating interaction terms between variables or normalizing features to see if hidden relationships emerge.<br>
# Exploring Non-linear Relationships: Since the linear correlations are weak, explore non-linear relationships between these variables. Methods like decision trees or random forests can help identify more complex patterns that are not captured in this heatmap.
